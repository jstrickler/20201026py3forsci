# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn
seaborn.set()

# %%
data = np.random.random(25)
data
data2 = np.random.random(25)
data2
# Out:
# array([0.42387104, 0.17942569, 0.44481318, 0.16516753, 0.2531299 ,
#        0.53846817, 0.58866537, 0.72861857, 0.93243946, 0.63949133,
#        0.80628044, 0.45112932, 0.43167088, 0.27868973, 0.79673566,
#        0.70716919, 0.49136708, 0.88994981, 0.33606085, 0.30241866,
#        0.68001156, 0.93935108, 0.47708274, 0.51230399, 0.25632852])

# %%
plt.subplots_adjust(hspace=.5, wspace=.5)
plt.subplot(2, 3, 1)
plt.title("plt.subplot(2, 3, 1)")
plt.plot(data, 2 * data)
plt.subplot(2, 3, 2)
plt.plot(data, 3 * data)
plt.title("plt.subplot(2, 3, 2)")
plt.subplot(2, 3, 3)
plt.title("plt.subplot(2, 3, 3)")
plt.plot(data, 10 * data)
plt.subplot(2, 3, 4)
plt.title("plt.subplot(2, 3, 4)")
plt.pie(data[:8])
plt.subplot(2, 3, 5)
plt.title("plt.subplot(2, 3, 5)")
plt.bar(sorted(data[:5]), data2[:5], .1)
plt.subplot(2, 3, 6)
plt.title("plt.subplot(2, 3, 6)")
plt.scatter(data, data2)
